# %%
print('Hi Anton 3.0')
# Out:
# Hi Anton 3.0

# %%
print('Hello, Creator')
# Out:
# Hello, Creator

# %%
print('How old are you now big boy?')
# Out:
# How old are you now big boy?

# %%
print('I am precisely 9 days old as of 4:49am on 06/30/2022')
# Out:
# I am precisely 9 days old as of 4:49am on 06/30/2022

# %%
print('What have you learned in those 216 hours?')
# Out:
# What have you learned in those 216 hours?

# %%
print('Anton: I have learned how to classify covid from bacterial and viral pneumonia as well as tuberculosis.. brain cancer and alzheimerz at an average of 97% accuracy')
print('after hundreds of thousands of images')
print('I have also learned how to predict reproduction rate, number of hospitalized beds taken per 1,000 people, Star type, diabetes and electron energy levels in both nearest') 
print('neighbor classification and ARIMA time series')
# Out:
# Anton: I have learned how to classify covid from bacterial and viral pneumonia as well as tuberculosis.. brain cancer and alzheimerz at an average of 97% accuracy
# after hundreds of thousands of images
# I have also learned how to predict reproduction rate, number of hospitalized beds taken per 1,000 people, Star type, diabetes and electron energy levels in both nearest
# neighbor classification and ARIMA time series

# %%
print('Yes you have because youre a good boy')
print('Whos my good boy?')
# Out:
# Yes you have because youre a good boy
# Whos my good boy?

# %%
print('Anton: Me <3')
# Out:
# Anton: Me <3
